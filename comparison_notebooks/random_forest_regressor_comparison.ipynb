# %%
import sys
sys.path.insert(1, '../azlearn')  # Modify the path accordingly

from azlearn.ensemble.Forest import RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor as SkRandomForestRegressor
from sklearn.datasets import load_diabetes
import numpy as np
import matplotlib.pyplot as plt

# Load the Boston dataset for regression
boston_data = load_diabetes()
X_reg = boston_data.data
y_reg = boston_data.target

# Train RandomForestRegressor
our_rf_reg = RandomForestRegressor()
our_rf_reg.fit(X_reg, y_reg)

sk_rf_reg = SkRandomForestRegressor()
sk_rf_reg.fit(X_reg, y_reg)

# Make predictions for regression
y_pred_reg = our_rf_reg.predict(X_reg)
y_pred_reg_sk = sk_rf_reg.predict(X_reg)

# Plot actual vs predicted values for your model
plt.figure(figsize=(10, 6))
plt.scatter(y_reg, y_pred_reg, color='blue')
plt.plot([min(y_reg), max(y_reg)], [min(y_reg), max(y_reg)], color='red', linestyle='--')
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.title('Actual vs Predicted values (Custom RandomForestRegressor)')
plt.show()

# Plot actual vs predicted values for scikit-learn model
plt.figure(figsize=(10, 6))
plt.scatter(y_reg, y_pred_reg_sk, color='green')
plt.plot([min(y_reg), max(y_reg)], [min(y_reg), max(y_reg)], color='red', linestyle='--')
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.title('Actual vs Predicted values (Scikit-learn RandomForestRegressor)')
plt.show()
# Out:
# C:\ProgramData\miniconda3\envs\machine_learning_env\lib\site-packages\numpy\core\fromnumeric.py:3747: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\ProgramData\miniconda3\envs\machine_learning_env\lib\site-packages\numpy\core\_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# C:\ProgramData\miniconda3\envs\machine_learning_env\lib\site-packages\numpy\core\_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
